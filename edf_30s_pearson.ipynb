# %%
import pandas as pd
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import pearsonr
from scipy import stats
from scipy.io import loadmat
from sklearn.cluster.bicluster import SpectralBiclustering, SpectralCoclustering

import cPickle
from eegtools.io import load_edf

# %%
data = load_edf("suj5_d2_nap-export.edf")[0]
print len(data), len(data[0])
# Out:
# 64 3383768

# %%
length_of_intervals = 30000
channels = 63
edges = 2016
total_interval = len(data[0])/length_of_intervals + 1
channels_data = [[None for j in range(edges)] for i in range(total_interval)]

# %%
def calculate_pearson(interval):
    index_counter = 0
    j = length_of_intervals * interval
    for start in range(channels):
        for index in range(channels):
            if start <= index:
                if interval != total_interval:
                    channels_data[interval][index_counter] = pearsonr(data[start][j:j + length_of_intervals],
                                                                     data[index][j:j + length_of_intervals])[0]
                else:
                    channels_data[interval][index_counter] = pearsonr(data[start][j:], data[index][j:])[0]
                index_counter += 1
    print index_counter

    
# def dump_edf_pearson():
#     with open('edf_30second_dump.dump', 'wb') as f:
#         cPickle.dump(channels_data, f)

# %%
for i in range(total_interval):
    print 'Calculating Interval %s' % i,
    calculate_pearson(i)
# Out:
# Calculating Interval 0 2016
# Calculating Interval 1 2016
# Calculating Interval 2 2016
# Calculating Interval 3 2016
# Calculating Interval 4 2016
# Calculating Interval 5 2016
# Calculating Interval 6 2016
# Calculating Interval 7 2016
# Calculating Interval 8 2016
# Calculating Interval 9 2016
# Calculating Interval 10 2016
# Calculating Interval 11 2016
# Calculating Interval 12 2016
# Calculating Interval 13 2016
# Calculating Interval 14 2016
# Calculating Interval 15 2016
# Calculating Interval 16 2016
# Calculating Interval 17 2016
# Calculating Interval 18 2016
# Calculating Interval 19 2016
# Calculating Interval 20 2016
# Calculating Interval 21 2016
# Calculating Interval 22 2016
# Calculating Interval 23 2016
# Calculating Interval 24 2016
# Calculating Interval 25 2016
# Calculating Interval 26 2016
# Calculating Interval 27 2016
# Calculating Interval 28 2016
# Calculating Interval 29 2016
# Calculating Interval 30 2016
# Calculating Interval 31 2016
# Calculating Interval 32 2016
# Calculating Interval 33 2016
# Calculating Interval 34 2016
# Calculating Interval 35 2016
# Calculating Interval 36 2016
# Calculating Interval 37 2016
# Calculating Interval 38 2016
# Calculating Interval 39 2016
# Calculating Interval 40 2016
# Calculating Interval 41 2016
# Calculating Interval 42 2016
# Calculating Interval 43 2016
# Calculating Interval 44 2016
# Calculating Interval 45 2016
# Calculating Interval 46 2016
# Calculating Interval 47 2016
# Calculating Interval 48 2016
# Calculating Interval 49 2016
# Calculating Interval 50 2016
# Calculating Interval 51 2016
# Calculating Interval 52 2016
# Calculating Interval 53 2016
# Calculating Interval 54 2016
# Calculating Interval 55 2016
# Calculating Interval 56 2016
# Calculating Interval 57 2016
# Calculating Interval 58 2016
# Calculating Interval 59 2016
# Calculating Interval 60 2016
# Calculating Interval 61 2016
# Calculating Interval 62 2016
# Calculating Interval 63 2016
# Calculating Interval 64 2016
# Calculating Interval 65 2016
# Calculating Interval 66 2016
# Calculating Interval 67 2016
# Calculating Interval 68 2016
# Calculating Interval 69 2016
# Calculating Interval 70 2016
# Calculating Interval 71 2016
# Calculating Interval 72 2016
# Calculating Interval 73 2016
# Calculating Interval 74 2016
# Calculating Interval 75 2016
# Calculating Interval 76 2016
# Calculating Interval 77 2016
# Calculating Interval 78 2016
# Calculating Interval 79 2016
# Calculating Interval 80 2016
# Calculating Interval 81 2016
# Calculating Interval 82 2016
# Calculating Interval 83 2016
# Calculating Interval 84 2016
# Calculating Interval 85 2016
# Calculating Interval 86 2016
# Calculating Interval 87 2016
# Calculating Interval 88 2016
# Calculating Interval 89 2016
# Calculating Interval 90 2016
# Calculating Interval 91 2016
# Calculating Interval 92 2016
# Calculating Interval 93 2016
# Calculating Interval 94 2016
# Calculating Interval 95 2016
# Calculating Interval 96 2016
# Calculating Interval 97 2016
# Calculating Interval 98 2016
# Calculating Interval 99 2016
# Calculating Interval 100 2016
# Calculating Interval 101 2016
# Calculating Interval 102 2016
# Calculating Interval 103 2016
# Calculating Interval 104 2016
# Calculating Interval 105 2016
# Calculating Interval 106 2016
# Calculating Interval 107 2016
# Calculating Interval 108 2016
# Calculating Interval 109 2016
# Calculating Interval 110 2016
# Calculating Interval 111 2016
# Calculating Interval 112 2016

# %%
print channels_data[0]
# Out:
# [1.0, 0.92418676817694057, 0.93464066936361034, 0.92534349252581605, 0.91685758438969023, 0.91942887113000149, 0.92077612250062124, -0.20269305059167014, 0.89169391104569207, 0.87420578178910069, 0.93755930403161825, 0.90404632381571359, 0.90351163125820233, 0.90084864714060109, 0.90608302939342023, 0.90612435625217624, 0.91346027484103887, 0.90086970630162599, 0.91724042327426214, 0.9036643993239809, 0.9181627285046069, 0.089727640388058055, 0.92069774994575104, 0.90545577095768093, 0.87922730044161934, 0.91570674671129881, 0.84834747941786692, 0.95213130281210556, 0.91830394027224793, 0.86019447770107116, 0.94476882259252226, 0.93909701839904802, 0.9664026412647001, 0.92270953002058997, 0.93017151412942012, 0.91866977923159665, 0.91560866353794834, 0.92406712009264991, 0.94344227629953747, 0.91435256053445191, 0.91949329339837238, 0.90614543854707408, 0.9128234675943725, 0.9078317605166647, 0.90098449698895533, 0.91438549783260437, 0.9041923521097992, 0.90271482053928032, 0.90446712695922893, 0.90701566170396453, 0.90345779644790003, 0.90351893458676569, 0.92976793254842705, 0.89446858600676171, 0.9086045938283398, 0.88274100668729927, 0.90821933293174817, 0.9040659316611388, 0.87943536625057606, 0.41980273086233211, 0.92489097684639621, 0.90862234981881584, 0.97403561115964377, 1.0, 0.99840545662850566, 0.98956711441817125, 0.99432595783589295, 0.99697293710233104, 0.99453597514671954, -0.32094115359080699, 0.98340185230496902, 0.98894088003782776, 0.93020047126687533, 0.98586326048409567, 0.98736401622436787, 0.98751133673579283, 0.99042765569223