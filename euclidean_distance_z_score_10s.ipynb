# %%
import pandas as pd
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import pearsonr
from scipy import stats
from scipy.io import loadmat
from sklearn.cluster.bicluster import SpectralBiclustering, SpectralCoclustering

import cPickle
from math import*

# %%
z_scores = np.load('raw_z_npdump.dump')
print len(z_scores), len(z_scores[0])
# Out:
# 64 3383768

# %%
length_of_intervals = 10000
channels = 63
edges = 2016
total_interval = len(z_scores[0])/length_of_intervals + 1
channels_data = [[None for j in range(edges)] for i in range(total_interval)] 
print total_interval, edges
# Out:
# 339 2016

# %%
def euc_dis(x, y):
    return sqrt(sum(pow(a-b,2) for a, b in zip(x, y)))

def calculate_euclidean(interval):
    index_counter = 0
    j = length_of_intervals * interval
    for start in range(channels):
        for index in range(channels):
            if start <= index:
                if interval != total_interval:
                    channels_data[interval][index_counter] = exp(-euc_dis(z_scores[start][j:j+length_of_intervals],
                                                                     z_scores[index][j:j+length_of_intervals]))
                else:
                    channels_data[interval][index_counter] = exp(-euc_dis(z_scores[start][j:],
                                                                     z_scores[index][j:]))
                index_counter += 1
    print index_counter

# %%
for i in range(total_interval):
    print 'Calculating Interval %s' % i,
    calculate_euclidean(i)
# Out:
# Calculating Interval 0 2016
# Calculating Interval 1 2016
# Calculating Interval 2 2016
# Calculating Interval 3 2016
# Calculating Interval 4 2016
# Calculating Interval 5

# %%
print channels_data[0]
# Out:
# [0.0, 72.97266197792372, 165.43650420874852, 75.9582699696545, 197.98016340471236, 334.8397596272161, 207.79335139919058, 15.21916626841564, 255.00248712834363, 276.1947843952477, 110.80203162985367, 59.7736177191657, 80.44806681962804, 78.68468031122835, 24.826768674891266, 184.08363030596632, 173.8024926135262, 143.97370142487173, 41.27885918950492, 281.7692869940485, 172.3061950532503, 4.700540860045228, 253.27385836923105, 154.74110292329334, 70.01530341909735, 228.78322806579848, 79.2634100129216, 186.52283961094307, 312.2684237937528, 176.7819784880112, 253.9075865467679, 98.17807673891417, 84.68407709855347, 224.16440047448646, 54.341744241285895, 295.1128904896251, 200.6781317700028, 48.316913317253636, 87.94086186134332, 233.337651128959, 264.8450189469343, 10.029475019546146, 190.6959399069445, 82.3005218981594, 160.15124599710273, 19.62957544640381, 164.53271256303938, 183.53739806707796, 208.26209200639082, 209.69508434827543, 6.74305857884055, 204.6487476279198, 88.31713475659446, 230.4939094132989, 305.6712022136843, 225.71668215397074, 86.77046439704533, 35.510298147799205, 154.4385797741409, 35.206013400354394, 166.21431981766085, 223.25409771102676, 42.75642963999381, 0.0, 93.19564837485494, 5.004631184921066, 269.72385562194836, 262.6596967672578, 135.274620000497, 65.42389692692704, 298.02266273574173, 347.69338020337705, 182.93495806061503

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-4f456fe61af7> in <module>()
#       1 pearson_data = np.array(channels_data)
#       2 spectral_model = SpectralBiclustering()
# ----> 3 spectral_model.fit(pearson_data)
#       4 fit_data = pearson_data[np.argsort(spectral_model.row_labels_)]
#       5 fit_data = fit_data[:, np.argsort(spectral_model.column_labels_)]
#
# C:\Users\Fioger\Anaconda2\lib\site-packages\sklearn\cluster\bicluster.pyc in fit(self, X)
#     120         X = check_array(X, accept_sparse='csr', dtype=np.float64)
#     121         self._check_parameters()
# --> 122         self._fit(X)
#     123
#     124     def _svd(self, array, n_components, n_discard):
#
# C:\Users\Fioger\Anaconda2\lib\site-packages\sklearn\cluster\bicluster.pyc in _fit(self, X)
#     442             normalized_data = _log_normalize(X)
#     443         n_discard = 0 if self.method == 'log' else 1
# --> 444         u, v = self._svd(normalized_data, n_sv, n_discard)
#     445         ut = u.T
#     446         vt = v.T
#
# C:\Users\Fioger\Anaconda2\lib\site-packages\sklearn\cluster\bicluster.pyc in _svd(self, array, n_components, n_discard)
#     133             u, _, vt = randomized_svd(array, n_components,
#     134                                       random_state=self.random_state,
# --> 135                                       **kwargs)
#     136
#     137         elif self.svd_method == 'arpack':
#
# C:\Users\Fioger\Anaconda2\lib\site-packages\sklearn\utils\extmath.pyc in randomized_svd(M, n_components, n_oversamples, n_iter, transpose, flip_sign, random_state)
#     295         M = M.T
#     296
# --> 297     Q = randomized_range_finder(M, n_random, n_iter, random_state)
#     298
#     299     # project M to the (k + p) dimensional space using the basis vectors
#
# C:\Users\Fioger\Anaconda2\lib\site-packages\sklearn\utils\extmath.pyc in randomized_range_finder(A, size, n_iter, random_state)
#     228
#     229     # extracting an orthonormal basis of the A range samples
# --> 230     Q, R = linalg.qr(Y, mode='economic')
#     231     return Q
#     232
#
# C:\Users\Fioger\Anaconda2\lib\site-packages\scipy\linalg\decomp_qr.pyc in qr(a, overwrite_a, lwork, mode, pivoting, check_finite)
#     124
#     125     if check_finite:
# --> 126         a1 = numpy.asarray_chkfinite(a)
#     127     else:
#     128         a1 = numpy.asarray(a)
#
# C:\Users\Fioger\Anaconda2\lib\site-packages\numpy\lib\function_base.pyc in asarray_chkfinite(a, dtype, order)
#     666     if a.dtype.char in typecodes['AllFloat'] and not np.isfinite(a).all():
#     667         raise ValueError(
# --> 668             "array must not contain infs or NaNs")
#     669     return a
#     670
#
# ValueError: array must not contain infs or NaNs

# %%
import json as simplejson
with open('media/euc_z_score_30s_2016.json', 'w+') as f:
    p = [[float(column) for column in row] for row in pearson_data]
    f.write(simplejson.dumps({'name': 's5d2nap', 'data': p}))
